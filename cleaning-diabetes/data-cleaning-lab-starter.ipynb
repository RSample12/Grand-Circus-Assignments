# %% [markdown]
# # Pima Data cleaning

# %%
# Import Modules Here
import pandas as pd
import numpy as np

# %% [markdown]
# ## Part 1: Read the Data into Jupyter

# %%
# Read the data into a dataframe named pima_df.
# YOUR CODE HERE
pima_df = pd.read_csv('diabetes_uncleaned_data.csv')

# %% [markdown]
# ## Part 2: Missing Data

# %%
#Question 1:  Find Columns with missing data
# YOUR CODE HERE
pima_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               890 non-null    float64
#  1   Glucose                   988 non-null    float64
#  2   BloodPressure             982 non-null    object
#  3   SkinThickness             1004 non-null   int64
#  4   Insulin                   1004 non-null   int64
#  5   BMI                       1003 non-null   object
#  6   DiabetesPedigreeFunction  1004 non-null   float64
#  7   Age                       982 non-null    float64
#  8   Outcome                   1004 non-null   object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 70.7+ KB

# %%
# Question 2:  Write code to remove rows with missing data and save the new dataframe as pima_missing_fixed_df
# YOUR CODE HERE
dropna_pima_df = pima_df.dropna()
dropna_pima_df
# Out:
#       Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 0             3.0    167.0            39             28      545  53.0
# 1            13.0    151.0           107             38    10000   9.2
# 2             8.0     59.0           109             18      739  59.1
# 4            10.0    165.0            48             37      737  39.4
# 5          -100.0    142.0            88             39       82  42.7
# ...           ...      ...           ...            ...      ...   ...
# 998           6.0    110.0            26             27      590  20.8
# 999           6.0    110.0            26             27      590  20.8
# 1001          4.0     80.0            24              6      268  48.9
# 1002          3.0    142.0         Error             10      299   4.8
# 1003          6.0    151.0            60             26      362  43.4
#
#       DiabetesPedigreeFunction    Age Outcome
# 0                        2.447  125.0   FALSE
# 1                        0.507  148.0   FALSE
# 2                        1.769   91.0    TRUE
# 4                        0.729   73.0   FALSE
# 5                        1.369  148.0    TRUE
# ...                        ...    ...     ...
# 998                      1.185   95.0   FALSE
# 999                      1.185   95.0   FALSE
# 1001                     0.989   81.0    TRUE
# 1002                     2.411   71.0    TRUE
# 1003                     2.027   23.0   FALSE
#
# [840 rows x 9 columns]

# %%
# Question 3:  Print out the number of rows in the dataframe.
# YOUR CODE HERE
dropna_pima_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 840 entries, 0 to 1003
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               840 non-null    float64
#  1   Glucose                   840 non-null    float64
#  2   BloodPressure             840 non-null    object
#  3   SkinThickness             840 non-null    int64
#  4   Insulin                   840 non-null    int64
#  5   BMI                       840 non-null    object
#  6   DiabetesPedigreeFunction  840 non-null    float64
#  7   Age                       840 non-null    float64
#  8   Outcome                   840 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 65.6+ KB

# %% [markdown]
# ### Question 4:  Discuss why this could be a problem.  What other methods could you use in this situation?
#
# Dropping every row with a missing value could drop more rows than intended causing our data set to be less effective. Instead we could fill missing values with the average value, or drop rows with certain values missing.

# %% [markdown]
# ## Part 3: Duplicated Data

# %%
# Question 1: find the rows of duplicated data in the 
# pima_missing_fixed_df and print them.  
dup_df = pima_df[pima_df.duplicated()]
dup_df
# Out:
#       Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 925           6.0     39.0            46              2      287  40.4
# 926          10.0     67.0            39             12      168  53.4
# 999           6.0    110.0            26             27      590  20.8
# 1003          6.0    151.0            60             26      362  43.4
#
#       DiabetesPedigreeFunction   Age Outcome
# 925                      2.394  60.0    TRUE
# 926                      0.162  71.0   FALSE
# 999                      1.185  95.0   FALSE
# 1003                     2.027  23.0   FALSE

# %%
# Question 2: Write code to remove rows with missing data 
# and save the new dataframe as pima_missing_fixed_df
pima_missing_fixed_df = pima_df.drop_duplicates(keep='last')
pima_missing_fixed_df
# Out:
#       Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 0             3.0    167.0            39             28      545  53.0
# 1            13.0    151.0           107             38    10000   9.2
# 2             8.0     59.0           109             18      739  59.1
# 3            11.0    132.0            83             11      376   4.1
# 4            10.0    165.0            48             37      737  39.4
# ...           ...      ...           ...            ...      ...   ...
# 999           6.0    110.0            26             27      590  20.8
# 1000          6.0      NaN            10              4      640  55.7
# 1001          4.0     80.0            24              6      268  48.9
# 1002          3.0    142.0         Error             10      299   4.8
# 1003          6.0    151.0            60             26      362  43.4
#
#       DiabetesPedigreeFunction    Age Outcome
# 0                        2.447  125.0   FALSE
# 1                        0.507  148.0   FALSE
# 2                        1.769   91.0    TRUE
# 3                        2.772    NaN    TRUE
# 4                        0.729   73.0   FALSE
# ...                        ...    ...     ...
# 999                      1.185   95.0   FALSE
# 1000                     2.483   79.0   FALSE
# 1001                     0.989   81.0    TRUE
# 1002                     2.411   71.0    TRUE
# 1003                     2.027   23.0   FALSE
#
# [1000 rows x 9 columns]

# %%
# Question 3:  Print out the number of rows in the dataframe.
print(len(pima_df))
print(len(pima_missing_fixed_df))
# Out:
# 1004
# 1000

# %% [markdown]
# ### Question 4:  In your jupyter notebook, discuss why this could be a problem.
# ### What other methods could you use in this situation?
#
# Your discussion here

# %% [markdown]
# ## Part 4: Mis-typed Columns/Broken Data

# %%
# Question 1: find the columns where most of the data seems to be one type of data, and there seems to be a data error. 
# In the markdown, after exploring in code, add a markdown cell discussing which columns have the data error. 
pima_missing_fixed_df.head()
# Out:
#    Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 0          3.0    167.0            39             28      545  53.0
# 1         13.0    151.0           107             38    10000   9.2
# 2          8.0     59.0           109             18      739  59.1
# 3         11.0    132.0            83             11      376   4.1
# 4         10.0    165.0            48             37      737  39.4
#
#    DiabetesPedigreeFunction    Age Outcome
# 0                     2.447  125.0   FALSE
# 1                     0.507  148.0   FALSE
# 2                     1.769   91.0    TRUE
# 3                     2.772    NaN    TRUE
# 4                     0.729   73.0   FALSE

# %%
# Question 2: Remove the rows with data errors
pima_missing_fixed_df = pima_missing_fixed_df.replace('Error', np.nan)
pima_missing_fixed_df['BloodPressure'] = pd.to_numeric(pima_missing_fixed_df['BloodPressure'])
pima_missing_fixed_df['BMI'] = pd.to_numeric(pima_missing_fixed_df['BMI'])
pima_missing_fixed_df['Outcome'] = pima_missing_fixed_df['Outcome'] == 'TRUE'

# %% [markdown]
# Some cols had a string "Error" which affected col data types, so that was replaced with nan
# Outcome was true false, but in string form, so I turned them into boolean

# %%
# Question 3: After the data is fixed in your columns change the columns to the correct type and save this as the pima_fixed_columns_df.

# %%
# Question 4: Run pima_fixed_columns_df.info() to confirm the columns have changed.
pima_missing_fixed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1003
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               886 non-null    float64
#  1   Glucose                   984 non-null    float64
#  2   BloodPressure             976 non-null    float64
#  3   SkinThickness             1000 non-null   int64
#  4   Insulin                   1000 non-null   int64
#  5   BMI                       998 non-null    float64
#  6   DiabetesPedigreeFunction  1000 non-null   float64
#  7   Age                       978 non-null    float64
#  8   Outcome                   1000 non-null   bool
# dtypes: bool(1), float64(6), int64(2)
# memory usage: 71.3 KB

# %% [markdown]
# ## Part 5: Outlier Detection and Removal

# %%
# Question 1: Print out the Outliers in each column in the pima_fixed_columns_df dataframe, use the IQR method of outlier detection.
new_df = pima_missing_fixed_df
for col, series in pima_missing_fixed_df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].items():
    print(col)
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    outliers = (series > (Q1 - 1.5 * IQR)) & (series < (Q3 + 1.5 * IQR))
    new_df[col] = new_df[col][outliers]
    print(outliers)
# Out:
# Pregnancies
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 999     True
# 1000    True
# 1001    True
# 1002    True
# 1003    True
# Name: Pregnancies, Length: 1000, dtype: bool
# Glucose
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 999      True
# 1000    False
# 1001     True
# 1002     True
# 1003     True
# Name: Glucose, Length: 1000, dtype: bool
# BloodPressure
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 999      True
# 1000     True
# 1001     True
# 1002    False
# 1003     True
# Name: BloodPressure, Length: 1000, dtype: bool
# SkinThickness
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 999     True
# 1000    True
# 1001    True
# 1002    True
# 1003    True
# Name: SkinThickness, Length: 1000, dtype: bool
# Insulin
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 999      True
# 1000     True
# 1001     True
# 1002     True
# 1003     True
# Name: Insulin, Length: 1000, dtype: bool
# BMI
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 999     True
# 1000    True
# 1001    True
# 1002    True
# 1003    True
# Name: BMI, Length: 1000, dtype: bool
# DiabetesPedigreeFunction
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 999     True
# 1000    True
# 1001    True
# 1002    True
# 1003    True
# Name: DiabetesPedigreeFunction, Length: 1000, dtype: bool
# Age
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 999      True
# 1000     True
# 1001     True
# 1002     True
# 1003     True
# Name: Age, Length: 1000, dtype: bool

# %%
# Question 2: Use loc to remove outliers in each of the columns that have outliers, save this as pima_outlier_removed_df.
pima_outlier_removed = new_df
pima_outlier_removed
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             3.0    167.0           39.0             28    545.0  53.0
# 1            13.0    151.0          107.0             38      NaN   9.2
# 2             8.0     59.0          109.0             18    739.0  59.1
# 3            11.0    132.0           83.0             11    376.0   4.1
# 4            10.0    165.0           48.0             37    737.0  39.4
# ...           ...      ...            ...            ...      ...   ...
# 999           6.0    110.0           26.0             27    590.0  20.8
# 1000          6.0      NaN           10.0              4    640.0  55.7
# 1001          4.0     80.0           24.0              6    268.0  48.9
# 1002          3.0    142.0            NaN             10    299.0   4.8
# 1003          6.0    151.0           60.0             26    362.0  43.4
#
#       DiabetesPedigreeFunction    Age  Outcome
# 0                        2.447  125.0    False
# 1                        0.507  148.0    False
# 2                        1.769   91.0     True
# 3                        2.772    NaN     True
# 4                        0.729   73.0    False
# ...                        ...    ...      ...
# 999                      1.185   95.0    False
# 1000                     2.483   79.0    False
# 1001                     0.989   81.0     True
# 1002                     2.411   71.0     True
# 1003                     2.027   23.0    False
#
# [1000 rows x 9 columns]

# %%
# Question 3:  Print out the row count in the pima_outlier_removed_df and confirm this number is correct.
print(pima_outlier_removed.count())
# Out:
# Pregnancies                  885
# Glucose                      984
# BloodPressure                974
# SkinThickness               1000
# Insulin                      999
# BMI                          998
# DiabetesPedigreeFunction     999
# Age                          978
# Outcome                     1000
# dtype: int64
